# %%
import sys  
sys.path.insert(0, './')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')
# %matplotlib inline

# %%
# Filtered to just Pearsl
df = pd.read_csv('../tutorial/tutorial.csv', index_col='timestamp', delimiter=';')
df = df.loc[df['product']=='PEARLS']
df = df[['mid_price']]
df.head()
# Out:
#            mid_price
# timestamp
# 0            10001.5
# 100           9999.0
# 200          10000.0
# 300           9997.0
# 400          10001.0

# %%
plt.plot(df.mid_price)

# %%
percentile_values = df.mid_price.describe()
percentile_values
# Out:
# count     2000.000000
# mean      9999.993500
# std          1.493427
# min       9996.500000
# 25%       9999.750000
# 50%      10000.000000
# 75%      10000.000000
# max      10003.500000
# Name: mid_price, dtype: float64

# %%
plt.axhline(percentile_values[3], c='orange')
plt.axhline(df.quantile([0.15,0.85])['mid_price'].to_numpy()[0], c='black')
plt.axhline(percentile_values[4], c='green')
plt.axhline(percentile_values[5], c='yellow')
plt.axhline(percentile_values[6], c='red')
plt.axhline(df.quantile([0.15,0.85])['mid_price'].to_numpy()[1], c='brown')
plt.axhline(percentile_values[7], c='purple')
plt.plot(df.mid_price)

# %%
df.quantile([0.15,0.85])['mid_price']
# Out:
# 0.15     9999.0
# 0.85    10001.0
# Name: mid_price, dtype: float64
