# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy import stats

# %%
r1_dn2 = pd.read_csv('/Users/OliverSmirnov/Documents/GitHub/imc-2023/round5/data/trades_round_1_day_-2_wn.csv', sep=';')
r1_dn1 = pd.read_csv('/Users/OliverSmirnov/Documents/GitHub/imc-2023/round5/data/trades_round_1_day_-1_wn.csv', sep=';')
r1_d0 = pd.read_csv('/Users/OliverSmirnov/Documents/GitHub/imc-2023/round5/data/trades_round_1_day_0_wn.csv', sep=';')

r2_dn1 = pd.read_csv('/Users/OliverSmirnov/Documents/GitHub/imc-2023/round5/data/trades_round_2_day_-1_wn.csv', sep=';')
r2_d0 = pd.read_csv('/Users/OliverSmirnov/Documents/GitHub/imc-2023/round5/data/trades_round_2_day_0_wn.csv', sep=';')
r2_d1 = pd.read_csv('/Users/OliverSmirnov/Documents/GitHub/imc-2023/round5/data/trades_round_2_day_1_wn.csv', sep=';')

r3_d0 = pd.read_csv('/Users/OliverSmirnov/Documents/GitHub/imc-2023/round5/data/trades_round_3_day_0_wn.csv', sep=';')
r3_d1 = pd.read_csv('/Users/OliverSmirnov/Documents/GitHub/imc-2023/round5/data/trades_round_3_day_1_wn.csv', sep=';')
r3_d2 = pd.read_csv('/Users/OliverSmirnov/Documents/GitHub/imc-2023/round5/data/trades_round_3_day_2_wn.csv', sep=';')

r4_d1 = pd.read_csv('/Users/OliverSmirnov/Documents/GitHub/imc-2023/round5/data/trades_round_4_day_1_wn.csv', sep=';')
r4_d2 = pd.read_csv('/Users/OliverSmirnov/Documents/GitHub/imc-2023/round5/data/trades_round_4_day_2_wn.csv', sep=';')
r4_d3 = pd.read_csv('/Users/OliverSmirnov/Documents/GitHub/imc-2023/round5/data/trades_round_4_day_3_wn.csv', sep=';')

# %%
pearls_dn2 = r1_dn2.loc[(r1_dn2['symbol'] == 'PEARLS')]
pearls_dn1 = r1_dn1.loc[(r1_dn1['symbol'] == 'PEARLS')]
pearls_d0 = r1_d0.loc[(r1_d0['symbol'] == 'PEARLS')]
pearls_d1 = r2_d1.loc[(r2_d1['symbol'] == 'PEARLS')]
pearls_d2 = r3_d2.loc[(r3_d2['symbol'] == 'PEARLS')]
pearls_d3 = r4_d3.loc[(r4_d3['symbol'] == 'PEARLS')]

print(pearls_d3['buyer'].unique())

plt.hist(pearls_dn2.price)
plt.show()
plt.hist(pearls_dn1.price)
plt.show()
plt.hist(pearls_d0.price)
plt.show()
plt.hist(pearls_d1.price)
plt.show()
plt.hist(pearls_d2.price)
plt.show()
plt.hist(pearls_d3.price)
plt.show()
# Out:
# ['Charlie' 'Gina' 'Caesar' 'Camilla' 'Paris' 'Pablo' 'Penelope' 'Gary']

# %%
bananas_dn2 = r1_dn2.loc[(r1_dn2['symbol'] == 'BANANAS')]
bananas_dn2 = bananas_dn2.loc[(bananas_dn2['price']!=0.0)]
bananas_dn1 = r1_dn1.loc[(r1_dn1['symbol'] == 'BANANAS')]
bananas_d0 = r1_d0.loc[(r1_d0['symbol'] == 'BANANAS')]
bananas_d1 = r2_d1.loc[(r2_d1['symbol'] == 'BANANAS')]
bananas_d2 = r3_d2.loc[(r3_d2['symbol'] == 'BANANAS')]
bananas_d3 = r4_d3.loc[(r4_d3['symbol'] == 'BANANAS')]

print(bananas_d3['buyer'].unique())

for monkey in bananas_d3['buyer'].unique():
    bananas_dn2_monkey_buy = bananas_dn2.loc[(bananas_dn2['buyer'] == monkey)]
    bananas_dn2_monkey_sell = bananas_dn2.loc[(bananas_dn2['seller'] == monkey)]
    print(monkey)
    plt.scatter(bananas_dn2_monkey_buy.timestamp, bananas_dn2_monkey_buy.price, s=2, c='green')
    plt.scatter(bananas_dn2_monkey_sell.timestamp, bananas_dn2_monkey_sell.price, s=2, c='red')
    plt.show()

plt.scatter(bananas_dn1.timestamp, bananas_dn1.price, s=2)
plt.show()
plt.scatter(bananas_d0.timestamp, bananas_d0.price, s=2)
plt.show()
plt.scatter(bananas_d1.timestamp, bananas_d1.price, s=2)
plt.show()
plt.scatter(bananas_d2.timestamp, bananas_d2.price, s=2)
plt.show()
plt.scatter(bananas_d3.timestamp, bananas_d3.price, s=2)
plt.show()
# Out:
# ['Paris' 'Charlie' 'Caesar' 'Pablo' 'Gina' 'Penelope' 'Camilla' 'Gary'
#  'Olivia']
# Paris
# Charlie
# Caesar
# Pablo
# Gina
# Penelope
# Camilla
# Gary
# Olivia

# %%
coconuts_dn1 = r2_dn1.loc[(r2_dn1['symbol'] == 'COCONUTS')]
coconuts_d0 = r2_d0.loc[(r2_d0['symbol'] == 'COCONUTS')]
coconuts_d1 = r2_d1.loc[(r2_d1['symbol'] == 'COCONUTS')]
coconuts_d2 = r3_d2.loc[(r3_d2['symbol'] == 'COCONUTS')]
coconuts_d3 = r4_d3.loc[(r4_d3['symbol'] == 'COCONUTS')]

print(coconuts_d3['buyer'].unique())

plt.scatter(coconuts_d3.timestamp, coconuts_d3.price, s=2, c="blue")
plt.show()
for monkey in coconuts_d3['buyer'].unique():
    coconuts_d3_monkey_buy = coconuts_d3.loc[(coconuts_d3['buyer'] == monkey)]
    coconuts_d3_monkey_sell = coconuts_d3.loc[(coconuts_d3['seller'] == monkey)]
    print(monkey)
    plt.scatter(coconuts_d3_monkey_buy.timestamp, coconuts_d3_monkey_buy.price, s=2, c='green')
    plt.scatter(coconuts_d3_monkey_sell.timestamp, coconuts_d3_monkey_sell.price, s=2, c='red')
    plt.show()

"""
plt.scatter(coconuts_dn1.timestamp, coconuts_dn1.price, s=3)
plt.show()
plt.scatter(coconuts_d0.timestamp, coconuts_d0.price, s=3)
plt.show()
plt.scatter(coconuts_d1.timestamp, coconuts_d1.price, s=3)
plt.show()
plt.scatter(coconuts_d2.timestamp, coconuts_d2.price, s=3)
plt.show()
plt.scatter(coconuts_d3.timestamp, coconuts_d3.price, s=3)
plt.show()
"""
# Out:
# ['Caesar' 'Charlie' 'Peter' 'Pablo']
# Caesar
# Charlie
# Peter
# Pablo
# '\nplt.scatter(coconuts_dn1.timestamp, coconuts_dn1.price, s=3)\nplt.show()\nplt.scatter(coconuts_d0.timestamp, coconuts_d0.price, s=3)\nplt.show()\nplt.scatter(coconuts_d1.timestamp, coconuts_d1.price, s=3)\nplt.show()\nplt.scatter(coconuts_d2.timestamp, coconuts_d2.price, s=3)\nplt.show()\nplt.scatter(coconuts_d3.timestamp, coconuts_d3.price, s=3)\nplt.show()\n'

# %%
pina_coladas_dn1 = r2_dn1.loc[(r2_dn1['symbol'] == 'PINA_COLADAS')]
pina_coladas_d0 = r2_d0.loc[(r2_d0['symbol'] == 'PINA_COLADAS')]
pina_coladas_d1 = r2_d1.loc[(r2_d1['symbol'] == 'PINA_COLADAS')]
pina_coladas_d2 = r3_d2.loc[(r3_d2['symbol'] == 'PINA_COLADAS')]
pina_coladas_d3 = r4_d3.loc[(r4_d3['symbol'] == 'PINA_COLADAS')]

print(pina_coladas_d3['buyer'].unique())

plt.scatter(pina_coladas_dn1.timestamp, pina_coladas_dn1.price, s=3)
plt.show()
plt.scatter(pina_coladas_d0.timestamp, pina_coladas_d0.price, s=3)
plt.show()
plt.scatter(pina_coladas_d1.timestamp, pina_coladas_d1.price, s=3)
plt.show()
plt.scatter(pina_coladas_d2.timestamp, pina_coladas_d2.price, s=3)
plt.show()
plt.scatter(pina_coladas_d3.timestamp, pina_coladas_d3.price, s=3)
plt.show()
# Out:
# ['Peter' 'Caesar' 'Charlie' 'Pablo']

# %%
diving_gear_d0 = r3_d0.loc[(r3_d0['symbol'] == 'DIVING_GEAR')]
diving_gear_d1 = r3_d1.loc[(r3_d1['symbol'] == 'DIVING_GEAR')]
diving_gear_d2 = r3_d2.loc[(r3_d2['symbol'] == 'DIVING_GEAR')]
diving_gear_d3 = r4_d3.loc[(r4_d3['symbol'] == 'DIVING_GEAR')]

print(diving_gear_d3['buyer'].unique())

for monkey in diving_gear_d3['buyer'].unique():
    diving_gear_d3_monkey_buy = diving_gear_d3.loc[(diving_gear_d3['buyer'] == monkey)]
    diving_gear_d3_monkey_sell = diving_gear_d3.loc[(diving_gear_d3['seller'] == monkey)]
    print(monkey)
    plt.scatter(diving_gear_d3_monkey_buy.timestamp, diving_gear_d3_monkey_buy.price, s=2, c='green')
    plt.scatter(diving_gear_d3_monkey_sell.timestamp, diving_gear_d3_monkey_sell.price, s=2, c='red')
    plt.show()

"""
plt.scatter(diving_gear_d0.timestamp, diving_gear_d0.price, s=3)
plt.show()
plt.scatter(diving_gear_d1.timestamp, diving_gear_d1.price, s=3)
plt.show()
plt.scatter(diving_gear_d2.timestamp, div ing_gear_d2.price, s=3)
plt.show()
plt.scatter(diving_gear_d3.timestamp, diving_gear_d3.price, s=3)
plt.show()
"""
# Out:
# ['Camilla' 'Paris' 'Charlie']
# Camilla
# Paris
# Charlie
# '\nplt.scatter(diving_gear_d0.timestamp, diving_gear_d0.price, s=3)\nplt.show()\nplt.scatter(diving_gear_d1.timestamp, diving_gear_d1.price, s=3)\nplt.show()\nplt.scatter(diving_gear_d2.timestamp, diving_gear_d2.price, s=3)\nplt.show()\nplt.scatter(diving_gear_d3.timestamp, diving_gear_d3.price, s=3)\nplt.show()\n'

# %%
berries_d0 = r3_d0.loc[(r3_d0['symbol'] == 'BERRIES')]
berries_d1 = r3_d1.loc[(r3_d1['symbol'] == 'BERRIES')]
berries_d2 = r3_d2.loc[(r3_d2['symbol'] == 'BERRIES')]
berries_d3 = r4_d3.loc[(r4_d3['symbol'] == 'BERRIES')]

print(berries_d3['buyer'].unique())

plt.scatter(berries_d3.timestamp, berries_d3.price, s=2, c="blue")
plt.show()

for monkey in berries_d3['buyer'].unique():
    berries_d3_monkey_buy = berries_d3.loc[(berries_d3['buyer'] == monkey)]
    berries_d3_monkey_sell = berries_d3.loc[(berries_d3['seller'] == monkey)]
    print(monkey)
    plt.scatter(berries_d3_monkey_buy.timestamp, berries_d3_monkey_buy.price, s=2, c='green')
    plt.scatter(berries_d3_monkey_sell.timestamp, berries_d3_monkey_sell.price, s=2, c='red')
    plt.show()

    if monkey == "Olivia":
        berries_d0_monkey_buy = berries_d0.loc[(berries_d0['buyer'] == monkey)]
        berries_d0_monkey_sell = berries_d0.loc[(berries_d0['seller'] == monkey)]
        berries_d1_monkey_buy = berries_d1.loc[(berries_d1['buyer'] == monkey)]
        berries_d1_monkey_sell = berries_d1.loc[(berries_d1['seller'] == monkey)]
        berries_d2_monkey_buy = berries_d2.loc[(berries_d2['buyer'] == monkey)]
        berries_d2_monkey_sell = berries_d2.loc[(berries_d2['seller'] == monkey)]
        
        
        plt.scatter(berries_d0.timestamp, berries_d0.price, s=2, c="blue")
        plt.show()
        plt.scatter(berries_d0_monkey_buy.timestamp, berries_d0_monkey_buy.price, s=2, c='green')
        plt.scatter(berries_d0_monkey_sell.timestamp, berries_d0_monkey_sell.price, s=2, c='red')
        plt.show()
        plt.scatter(berries_d1.timestamp, berries_d1.price, s=2, c="blue")
        plt.show()
        plt.scatter(berries_d1_monkey_buy.timestamp, berries_d1_monkey_buy.price, s=2, c='green')
        plt.scatter(berries_d1_monkey_sell.timestamp, berries_d1_monkey_sell.price, s=2, c='red')
        plt.show()
        plt.scatter(berries_d2.timestamp, berries_d2.price, s=2, c="blue")
        plt.show()
        plt.scatter(berries_d2_monkey_buy.timestamp, berries_d2_monkey_buy.price, s=2, c='green')
        plt.scatter(berries_d2_monkey_sell.timestamp, berries_d2_monkey_sell.price, s=2, c='red')
        plt.show()
        plt.scatter(berries_d3.timestamp, berries_d3.price, s=2, c="blue")
        plt.show()
        plt.scatter(berries_d3_monkey_buy.timestamp, berries_d3_monkey_buy.price, s=2, c='green')
        plt.scatter(berries_d3_monkey_sell.timestamp, berries_d3_monkey_sell.price, s=2, c='red')
        plt.show()
    
"""
plt.scatter(berries_d0.timestamp, berries_d0.price, s=3)
plt.show()
plt.scatter(berries_d1.timestamp, berries_d1.price, s=3)
plt.show()
plt.scatter(berries_d2.timestamp, berries_d2.price, s=3)
plt.show()
plt.scatter(berries_d3.timestamp, berries_d3.price, s=3)
plt.show()
"""
# Out:
# ['Camilla' 'Paris' 'Penelope' 'Gary' 'Peter' 'Pablo' 'Charlie' 'Gina'
#  'Olivia']
# Camilla
# Paris
# Penelope
# Gary
# Peter
# Pablo
# Charlie
# Gina
# Olivia
# '\nplt.scatter(berries_d0.timestamp, berries_d0.price, s=3)\nplt.show()\nplt.scatter(berries_d1.timestamp, berries_d1.price, s=3)\nplt.show()\nplt.scatter(berries_d2.timestamp, berries_d2.price, s=3)\nplt.show()\nplt.scatter(berries_d3.timestamp, berries_d3.price, s=3)\nplt.show()\n'

# %%
dip_d1 = r4_d1.loc[(r4_d1['symbol'] == 'DIP')]
dip_d2 = r4_d2.loc[(r4_d2['symbol'] == 'DIP')]
dip_d3 = r4_d3.loc[(r4_d3['symbol'] == 'DIP')]

print(dip_d3['buyer'].unique())

plt.scatter(dip_d1.timestamp, dip_d1.price, s=3)
plt.show()
plt.scatter(dip_d2.timestamp, dip_d2.price, s=3)
plt.show()
plt.scatter(dip_d3.timestamp, dip_d3.price, s=3)
plt.show()
# Out:
# ['Caesar' 'Paris' 'Camilla']

# %%
baguette_d1 = r4_d1.loc[(r4_d1['symbol'] == 'BAGUETTE')]
baguette_d2 = r4_d2.loc[(r4_d2['symbol'] == 'BAGUETTE')]
baguette_d3 = r4_d3.loc[(r4_d3['symbol'] == 'BAGUETTE')]

print(baguette_d3['buyer'].unique())

plt.scatter(baguette_d1.timestamp, baguette_d1.price, s=3)
plt.show()
plt.scatter(baguette_d2.timestamp, baguette_d2.price, s=3)
plt.show()
plt.scatter(baguette_d3.timestamp, baguette_d3.price, s=3)
plt.show()
# Out:
# ['Paris' 'Caesar' 'Camilla']

# %%
ukulele_d1 = r4_d1.loc[(r4_d1['symbol'] == 'UKULELE')]
ukulele_d2 = r4_d2.loc[(r4_d2['symbol'] == 'UKULELE')]
ukulele_d3 = r4_d3.loc[(r4_d3['symbol'] == 'UKULELE')]

print(ukulele_d3['buyer'].unique())

plt.scatter(ukulele_d1.timestamp, ukulele_d1.price, s=3)
plt.show()
plt.scatter(ukulele_d2.timestamp, ukulele_d2.price, s=3)
plt.show()
plt.scatter(ukulele_d3.timestamp, ukulele_d3.price, s=3)
plt.show()

for monkey in ukulele_d3['buyer'].unique():
    ukulele_d3_monkey_buy = ukulele_d3.loc[(ukulele_d3['buyer'] == monkey)]
    ukulele_d3_monkey_sell = ukulele_d3.loc[(ukulele_d3['seller'] == monkey)]
    print(monkey)
    plt.scatter(ukulele_d3_monkey_buy.timestamp, ukulele_d3_monkey_buy.price, s=2, c='green')
    plt.scatter(ukulele_d3_monkey_sell.timestamp, ukulele_d3_monkey_sell.price, s=2, c='red')
    plt.show()
    
    if monkey == "Olivia":
        ukulele_d1_monkey_buy = ukulele_d1.loc[(ukulele_d1['buyer'] == monkey)]
        ukulele_d1_monkey_sell = ukulele_d1.loc[(ukulele_d1['seller'] == monkey)]
        ukulele_d2_monkey_buy = ukulele_d2.loc[(ukulele_d2['buyer'] == monkey)]
        ukulele_d2_monkey_sell = ukulele_d2.loc[(ukulele_d2['seller'] == monkey)]
        ukulele_d3_monkey_buy = ukulele_d3.loc[(ukulele_d3['buyer'] == monkey)]
        ukulele_d3_monkey_sell = ukulele_d3.loc[(ukulele_d3['seller'] == monkey)]
        
        plt.scatter(ukulele_d1.timestamp, ukulele_d1.price, s=2, c="blue")
        plt.show()
        plt.scatter(ukulele_d1_monkey_buy.timestamp, ukulele_d1_monkey_buy.price, s=2, c='green')
        plt.scatter(ukulele_d1_monkey_sell.timestamp, ukulele_d1_monkey_sell.price, s=2, c='red')
        plt.show()
        plt.scatter(ukulele_d2.timestamp, ukulele_d2.price, s=2, c="blue")
        plt.show()
        plt.scatter(ukulele_d2_monkey_buy.timestamp, ukulele_d2_monkey_buy.price, s=2, c='green')
        plt.scatter(ukulele_d2_monkey_sell.timestamp, ukulele_d2_monkey_sell.price, s=2, c='red')
        plt.show()
        plt.scatter(ukulele_d3.timestamp, ukulele_d3.price, s=2, c="blue")
        plt.show()
        plt.scatter(ukulele_d3_monkey_buy.timestamp, ukulele_d3_monkey_buy.price, s=2, c='green')
        plt.scatter(ukulele_d3_monkey_sell.timestamp, ukulele_d3_monkey_sell.price, s=2, c='red')
        plt.show()
# Out:
# ['Paris' 'Caesar' 'Camilla' 'Olivia']
# Paris
# Caesar
# Camilla
# Olivia

# %%
picnic_basket_d1 = r4_d1.loc[(r4_d1['symbol'] == 'PICNIC_BASKET')]
picnic_basket_d2 = r4_d2.loc[(r4_d2['symbol'] == 'PICNIC_BASKET')]
picnic_basket_d3 = r4_d3.loc[(r4_d3['symbol'] == 'PICNIC_BASKET')]

print(picnic_basket_d3['buyer'].unique())

plt.scatter(picnic_basket_d1.timestamp, picnic_basket_d1.price, s=3)
plt.show()
plt.scatter(picnic_basket_d2.timestamp, picnic_basket_d2.price, s=3)
plt.show()
plt.scatter(picnic_basket_d3.timestamp, picnic_basket_d3.price, s=3)
plt.show()
# Out:
# ['Camilla' 'Penelope' 'Pablo' 'Caesar']
