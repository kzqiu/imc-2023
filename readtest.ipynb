# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tutorial.csv', delimiter=';')

# %%
df.head(10)
# Out:
#    day  timestamp  product  bid_price_1  bid_volume_1  bid_price_2  \
# 0   -1          0   PEARLS         9998             1       9995.0
# 1   -1          0  BANANAS         4946             1       4945.0
# 2   -1        100   PEARLS         9996             1       9995.0
# 3   -1        100  BANANAS         4945            31          NaN
# 4   -1        200  BANANAS         4945            22          NaN
# 5   -1        200   PEARLS         9996             1       9995.0
# 6   -1        300   PEARLS         9996             2       9995.0
# 7   -1        300  BANANAS         4945            25          NaN
# 8   -1        400   PEARLS         9998             5       9996.0
# 9   -1        400  BANANAS         4946             5       4945.0
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0          30.0          NaN           NaN        10005            30
# 1          30.0          NaN           NaN         4952            30
# 2          30.0          NaN           NaN        10002             6
# 3           NaN          NaN           NaN         4950             7
# 4           NaN          NaN           NaN         4951             1
# 5          21.0          NaN           NaN        10004             1
# 6          23.0          NaN           NaN         9998             3
# 7           NaN          NaN           NaN         4952            25
# 8           2.0       9995.0          23.0        10004             2
# 9          25.0          NaN           NaN         4952            25
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 0          NaN           NaN          NaN           NaN    10001.5
# 1          NaN           NaN          NaN           NaN     4949.0
# 2      10004.0           1.0      10005.0          30.0     9999.0
# 3       4952.0          31.0          NaN           NaN     4947.5
# 4       4952.0          21.0          NaN           NaN     4948.0
# 5      10005.0          21.0          NaN           NaN    10000.0
# 6      10004.0           2.0      10005.0          23.0     9997.0
# 7          NaN           NaN          NaN           NaN     4948.5
# 8      10005.0          23.0          NaN           NaN    10001.0
# 9          NaN           NaN          NaN           NaN     4949.0
#
#    profit_and_loss
# 0         0.000000
# 1         0.000000
# 2        -2.000000
# 3        -2.555664
# 4        -2.204590
# 5        -6.000000
# 6       -10.000000
# 7        -2.395996
# 8       -18.000000
# 9        -2.662598

# %%
mids = df.filter(items=['timestamp', 'product', 'mid_price'])
mids.head()
# Out:
#    timestamp  product  mid_price
# 0          0   PEARLS    10001.5
# 1          0  BANANAS     4949.0
# 2        100   PEARLS     9999.0
# 3        100  BANANAS     4947.5
# 4        200  BANANAS     4948.0

# %%
pearls = mids[mids['product'] == 'PEARLS']
pearls.head()
# Out:
#    timestamp product  mid_price
# 0          0  PEARLS    10001.5
# 2        100  PEARLS     9999.0
# 5        200  PEARLS    10000.0
# 6        300  PEARLS     9997.0
# 8        400  PEARLS    10001.0

# %%
x = pearls['timestamp'][:25]
# y = np.log(pearls['mid_price'].to_numpy())
y = pearls['mid_price'][:25]

plt.figure(figsize=(15, 8))
plt.title('Pearls Mid-Price vs Time')
plt.xlabel('Timestamp')
plt.ylabel('Log of Mid-Price')
# plt.plot(x, y, linewidth=1)
plt.scatter(x, y)
plt.show()

# %%
bananas = mids[mids['product'] == 'BANANAS']
bananas.head()
# Out:
#    timestamp  product  mid_price
# 1          0  BANANAS     4949.0
# 3        100  BANANAS     4947.5
# 4        200  BANANAS     4948.0
# 7        300  BANANAS     4948.5
# 9        400  BANANAS     4949.0

# %%
x = bananas['timestamp']
y = np.log(bananas['mid_price'].to_numpy())
# y = bananas['mid_price']

plt.figure(figsize=(15, 8))
plt.title('Bananas Mid-Price vs Time')
plt.xlabel('Timestamp')
plt.ylabel('Log of Mid-Price')
plt.plot(x, y, linewidth=1)
plt.show()
